# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as pit
import scipy .stats as st
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # task 1

# %%
n=25
p=.25
q=1-p
s=np.arange(4)
b=st.binom.pmf(s,n,p)
b
# Out:
# array([0.00075254, 0.0062712 , 0.02508478, 0.06410555])

# %%
#proboblity fever than 5
#a
n=25
p=.15
q=1-p
s=np.arange(4)
f=st.binom.pmf(s,n,p)
f
# Out:
# array([0.01719781, 0.07587269, 0.16067158, 0.2173792 ])

# %%
pit.plot(s,f,'go--')
pit.xlabel('no of purchaser chose oreo')
pit.ylabel('probiblity of purchacer choses oreo')
pit.title('binomal')
pit.show()

# %%
#proboblity more than 10
n=25
p=.15
q=1-p
k=np.arange(11,26)
j=st.binom.pmf(k,n,p)
j
# Out:
# array([3.96232795e-04, 8.15773402e-05, 1.43960012e-05, 2.17754640e-06,
#        2.81800123e-07, 3.10808959e-08, 2.90375152e-09, 2.27745217e-10,
#        1.48069646e-11, 7.83898125e-13, 3.29368960e-14, 1.05679880e-15,
#        2.43252921e-17, 3.57724884e-19, 2.52511683e-21])

# %%
pit.plot(k,j,'go--')
pit.xlabel('no of purchaser chose oreo')
pit.ylabel('probiblity of purchacer choses oreo')
pit.title('binomal')
pit.show()

# %%
#mean
d=st.binom.pmf(k,n,p).mean()
d
# Out:
# 3.297998075659336e-05

# %%
#standard devation
s=st.binom.pmf(k,n,p).std()
s
# Out:
# 9.918070059151965e-05

# %% [markdown]
# # task 2

# %%
#a no of probolity of the customer upto10
rate=3.5
x=np.arange(0,11)
a=st.poisson.pmf(x[0],rate)
a
# Out:
# 0.0301973834223185

# %%
# no of probolity of the customer more than 6
p=st.poisson.pmf(x,rate)
b=sum(p[6:])
b
# Out:
# 0.1413670524666047

# %%
# no of probolity of the customer 4 customer
rate_10=rate*2
c=st.poisson.cdf(3,rate_10)
c
# Out:
# 0.0817654162447216

# %%
# no of probolity of the customer 3 to 6
prob=st.poisson.pmf(x,rate_10)
d=sum(prob[3:7])
d
# Out:
# 0.42007489196817666

# %%
#e proboblity of exacrly 8 customer arrivesin 15 min
rate_15=rate*3
e=st.poisson.cdf(8,rate_15)
e
# Out:
# 0.2794130478623683

# %%
# sketch graph of all the above poission distrubution
c=st.poisson.pmf(np.arange(0,20),rate_10)

pit.plot(c,'go--')
pit.xlabel('no of purchaser chose oreo')
pit.ylabel('probiblity of purchacer choses oreo')
pit.title('binomal')
pit.show()
