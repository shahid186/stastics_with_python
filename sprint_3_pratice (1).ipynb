# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit
import statistics as st
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')
import statistics as st

# %%
data=pd.read_csv('DS1_C5_S3_Mtcars_Data_Practice.csv')
data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  210  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  210  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  210  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  205  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7  330  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  223  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0
# ...

# %%
d=data.sample(20,replace=False,random_state=1).sort_index()
d.reset_index(drop=True,inplace=False)

# %%
data.sample(20,replace=False,random_state=1)
# Out:
#                  model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 27        Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 3       Hornet 4 Drive  21.4    6  258.0  210  3.08  3.215  19.44   1   0
# 22         AMC Javelin  15.2    8  304.0  180  3.15  3.435  17.30   0   0
# 18         Honda Civic  30.4    4   75.7  280  4.93  1.615  18.52   1   1
# 23          Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 17            Fiat 128  32.4    4   78.7  340  4.08  2.200  19.47   1   1
# 21    Dodge Challenger  15.5    8  318.0  250  2.76  3.520  16.87   0   0
# 28      Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 19      Toyota Corolla  33.9    4   71.1  180  4.22  1.835  19.90   1   1
# 14  Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 24    Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 10           Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0
# ...

# %%
m=data.sample(20,replace=True,random_state=1)
m.reset_index(inplace=True)

# %%
n=data.sample(20,replace=False,random_state=1)

# %%
m=data.sample(50,replace=True,random-state=1)
# Out:
#   Cell In[7], line 1
#     m=data.sample(50,replace=True,random-state=1)
#                                   ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
b=data.sample(20,replace=False,random_state=1)

# %%
v=data.sample(20,replace=False,random_state=1)

# %%
d=data.sample(20,replace=False,random_state=1).sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 d=data.sample(20,replace=False,random_state=1).sort_values()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %% [markdown]
# # task 3.1.1

# %%
c=data.sample(20,replace=False,random_state=1).sort_index()
c.reset_index(drop=True,inplace=True)

# %%
n=data.sample(20,replace=True,random_state=1).sort_values()
n.reset_index(drop=True,inplace=True)

# %%
m=data.sample(20,replace=True,random_state=1).sort_values()
m.reset_index(drop=True,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 m=data.sample(20,replace=True,random_state=1).sort_values()
#       2 m.reset_index(drop=True,inplace=False)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
v=data.sample(20,replace=False,random_state=1).sort_index()
v.reset_index(drop=True,inplace=False)
# Out:
#                  model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 1       Hornet 4 Drive  21.4    6  258.0  210  3.08  3.215  19.44   1   0
# 2    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 3           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 4            Merc 240D  24.4    4  146.7  330  3.69  3.190  20.00   1   0
# 5            Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0
# 6          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 7   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 8             Fiat 128  32.4    4   78.7  340  4.08  2.200  19.47   1   1
# 9          Honda Civic  30.4    4   75.7  280  4.93  1.615  18.52   1   1
# 10      Toyota Corolla  33.9    4   71.1  180  4.22  1.835  19.90   1   1
# 11       Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# ...

# %%
#random sampling without  replacement
d=data.sample(20,replace=False,random_state=1).sort_index()
d.reset_index(drop=True,inplace=False)
# Out:
#                  model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 1       Hornet 4 Drive  21.4    6  258.0  210  3.08  3.215  19.44   1   0
# 2    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 3           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 4            Merc 240D  24.4    4  146.7  330  3.69  3.190  20.00   1   0
# 5            Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0
# 6          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 7   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 8             Fiat 128  32.4    4   78.7  340  4.08  2.200  19.47   1   1
# 9          Honda Civic  30.4    4   75.7  280  4.93  1.615  18.52   1   1
# 10      Toyota Corolla  33.9    4   71.1  180  4.22  1.835  19.90   1   1
# 11       Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# ...

# %%
data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
data['cyl'].replace(to_replace=[4],value=78,inplace=True)
data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  210  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  210  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8   78  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  210  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  205  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4   78  146.7  330  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8   78  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  223  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# # task 3.1.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
data['model']=data['model'].astype('str')

# %%
data['model']=data['model'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data['model']=data['model'].astype('int')
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
data.rename(columns={'cyl':'shahid'},inplace=True)
data
# Out:
#                   model   mpg  shahid   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0       6  160.0  210  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0       6  160.0  210  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8      78  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4       6  258.0  210  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7       8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1       6  225.0  205  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3       8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4      78  146.7  330  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8      78  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2       6  167.6  223  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8       6  167.6  223  3.92  3.440  18.90   1   0
# ...

# %%
data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
d=data.sample(45,replace=True,random_state=1)

# %%
#random sampling with replacement
d=data.sample(20,replace=True,random_state=1).sort_index()
d.reset_index(drop=True,inplace=False)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  210  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  210  3.90  2.875  17.02   0   1
# 2               Valiant  18.1    6  225.0  205  2.76  3.460  20.22   1   0
# 3               Valiant  18.1    6  225.0  205  2.76  3.460  20.22   1   0
# 4            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 5             Merc 240D  24.4    4  146.7  330  3.69  3.190  20.00   1   0
# 6              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 7              Merc 280  19.2    6  167.6  223  3.92  3.440  18.30   1   0
# 8            Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 9            Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 10           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# ...

# %% [markdown]
# # task 3.1.3

# %%
data[::2].reset_index(drop=True)
# Out:
#                  model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0            Mazda RX4  21.0    6  160.0  210  3.90  2.620  16.46   0   1
# 1           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 2    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 3           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 4             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 5            Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0
# 6           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 7   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 8    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 9          Honda Civic  30.4    4   75.7  280  4.93  1.615  18.52   1   1
# 10       Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 11         AMC Javelin  15.2    8  304.0  180  3.15  3.435  17.30   0   0
# ...

# %%
data[::2].reset_index(drop=True)

# %%
data[::2].reset_index(drop=False)

# %%
# systmatic sampling
data[::2].reset_index(drop=True)
# Out:
#                  model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0            Mazda RX4  21.0    6  160.0  210  3.90  2.620  16.46   0   1
# 1           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 2    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 3           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 4             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 5            Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0
# 6           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 7   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 8    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 9          Honda Civic  30.4    4   75.7  280  4.93  1.615  18.52   1   1
# 10       Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 11         AMC Javelin  15.2    8  304.0  180  3.15  3.435  17.30   0   0
# ...

# %%
f=data.groupby('vs')
name=data['vs'].unique()
d=pd.DataFrame()
for i in name:
    f=f.get_group(i)
    k=data.sample(20)
    d=d.append(k)
d.reset_index(drop=True,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 5
#       3 d=pd.DataFrame()
#       4 for i in name:
# ----> 5     f=f.get_group(i)
#       6     k=data.sample(20)
#       7     d=d.append(k)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
b=data.groupby('vs')
n=data['vs'].unique()
m=pd.DataFrame()
for i in n:
    x=b.get_group(i)
    l=x.sample(20)
    s=m.append(l)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 6
#       4 for i in n:
#       5     x=b.get_group(i)
# ----> 6     l=x.sample(20)
#       7     s=m.append(l)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:5773, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5770 if weights is not None:
#    5771     weights = sample.preprocess_weights(self, weights, axis)
# -> 5773 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5774 result = self.take(sampled_indices, axis=axis)
#    5776 if ignore_index:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# ...

# %%
b=data.groupby('vs')
n=data['vs'].unique()
m=pd.DataFrame()
for i in n:
    m=b.get_group(i)
    n=m.sample(20)
    m=m.append(n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 6
#       4 for i in n:
#       5     m=b.get_group(i)
# ----> 6     n=m.sample(20)
#       7     m=m.append(n)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:5773, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5770 if weights is not None:
#    5771     weights = sample.preprocess_weights(self, weights, axis)
# -> 5773 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5774 result = self.take(sampled_indices, axis=axis)
#    5776 if ignore_index:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# ...

# %%
h=data.groupby('vs')
n=data['vs'].unique()
b=pd.DataFrame()
for i in n:
    f=h.get_group(i)
    k=f.sample(29)
    x=k.append(k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       4 for i in n:
#       5     f=h.get_group(i)
# ----> 6     k=f.sample(29)
#       7     x=k.append(k)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:5773, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5770 if weights is not None:
#    5771     weights = sample.preprocess_weights(self, weights, axis)
# -> 5773 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5774 result = self.take(sampled_indices, axis=axis)
#    5776 if ignore_index:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# ...

# %%
data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
n=data.groupby('vs')
name=data['vs'].unique()
c=pd.DataFrame()
for i in name:
    f=n.get_group(i)
    k=f.sample(20)
    c=c.append(k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       4 for i in name:
#       5     f=n.get_group(i)
# ----> 6     k=f.sample(20)
#       7     c=c.append(k)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:5773, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5770 if weights is not None:
#    5771     weights = sample.preprocess_weights(self, weights, axis)
# -> 5773 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5774 result = self.take(sampled_indices, axis=axis)
#    5776 if ignore_index:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# ...

# %%
m=data.groupby('vs')
name=data['vs'].unique()
b=pd.DataFrame()
for i in name:
    v=m.get_group(i)
    n=v.sample(10)
    b=b.append(n)
b.reset_index(drop=True,inplace=True)

# %%
n=data.groupby('vs')
m=data['vs'].unique()
k=pd.DataFrame()
for i in m:
    q=n.get_group(i)
    b=q.sample(20)
    h=k.append(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 6
#       4 for i in m:
#       5     q=n.get_group(i)
# ----> 6     b=q.sample(20)
#       7     h=k.append(b)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:5773, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5770 if weights is not None:
#    5771     weights = sample.preprocess_weights(self, weights, axis)
# -> 5773 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5774 result = self.take(sampled_indices, axis=axis)
#    5776 if ignore_index:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\sample.py:150, in sample(obj_len, size, replace, weights, random_state)
#     147     else:
#     148         raise ValueError("Invalid weights: weights sum to zero")
# ...

# %%
data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
m=data.groupby('vs')
name=data['vs'].unique()
n=pd.DataFrame()
for i in name:
    b=m.get_groupby('vs')
    m=b.sample(20)
    k=n.append(m)
k.reset_index(drop=True,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       3 n=pd.DataFrame()
#       4 for i in name:
# ----> 5     b=m.get_groupby('vs')
#       6     m=b.sample(20)
#       7     k=n.append(m)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'get_groupby'

# %%
v=data.groupby('vs')
name=data['vs'].unique()
n=pd.DataFrame()
for i in name:
    f=v.get_group(i)
    m=f.sample(10)
    n=n.append(m)
n.reset_index(drop=True,inplace=True)

# %% [markdown]
# # task 3.1.4

# %%
#stratified sampling with respect to engine type
f=data.groupby('vs')
name=data['vs'].unique()
d=pd.DataFrame()
for i in name:
    g=f.get_group(i)
    k=g.sample(10)
    d=d.append(k)
d.reset_index(drop=True,inplace=True)  
d
# Out:
#                  model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 1        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 2        Porsche 914-2  26.0    4  120.3  320  4.43  2.140  16.70   0   1
# 3    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 4          AMC Javelin  15.2    8  304.0  180  3.15  3.435  17.30   0   0
# 5           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 6         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 7     Dodge Challenger  15.5    8  318.0  250  2.76  3.520  16.87   0   0
# 8     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 9           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 10          Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 11           Merc 240D  24.4    4  146.7  330  3.69  3.190  20.00   1   0
# ...

# %% [markdown]
# # task 3.1.5

# %%
#cluster sampling with respect to engine type
f=data.groupby('vs')
d=pd.DataFrame()
g=f.get_group(1)
k=g.sample(frac=.40)
d=d.append(k)
d.reset_index(drop=True)
# Out:
#            model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Merc 280C  17.8    6  167.6  223  3.92  3.440  18.90   1   0     4
# 1       Merc 280  19.2    6  167.6  223  3.92  3.440  18.30   1   0     4
# 2      Fiat X1-9  27.3    4   79.0  290  4.08  1.935  18.90   1   1     4
# 3        Valiant  18.1    6  225.0  205  2.76  3.460  20.22   1   0     3
# 4   Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 5  Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1

# %% [markdown]
# # task 3.2.1

# %%
#mean,mode,median and standard devation of random sampling 10
s_10=data.sample(n=10)
s_m=[s_10['disp'].mean(),
s_10['disp'].median(),
s_10['disp'].mode()[0],
s_10['disp'].std()]

# %%
s_10=data.sample(n=20)
s_m=[s_10['disp'].mean(),
    s_10['disp'].std(),
    s_10['disp'].median()]
s_10
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 18          Honda Civic  30.4    4   75.7  280  4.93  1.615  18.52   1   1
# 22          AMC Javelin  15.2    8  304.0  180  3.15  3.435  17.30   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  250  2.76  3.520  16.87   0   0
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 9              Merc 280  19.2    6  167.6  223  3.92  3.440  18.30   1   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# ...

# %%
m=pd.DataFrame()
m['measure']=['mean','median','mode','std']
m['disp']=s_m
s_m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 m=pd.DataFrame()
#       2 m['measure']=['mean','median','mode','std']
# ----> 3 m['disp']=s_m
#       4 s_m
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
# ...

# %%
s_10=data.sample(n=10)
s_m=[s_10['disp'].mean(),
s_10['disp'].median(),
s_10['disp'].mode()[0],
s_10['disp'].std()]

# %%
df=pd.DataFrame()
df['measure']=['mean','median','mode','std']
df['disp']=s_m
df
# Out:
#   measure        disp
# 0    mean  217.400000
# 1  median  172.650000
# 2    mode   75.700000
# 3     std  141.248261

# %%
s_10=data.sample(n=20)
s_n=[data['disp'].mean(),
data['disp'].median(),
data['disp'].mode()[0],
data['disp'] .std()]

# %%
s_10=data.sample(n=20)
sn=[s_10['disp'].mean(),
   s_10['disp'].median(),
   s_10['disp'].std()]

# %%
n=pd.DataFrame()
n['measutre']=['mean','median','std']
n['disp']=sn
sn
# Out:
# [221.115, 196.3, 114.05991627210673]

# %%
fg=pd.DataFrame()
fg['measure']=['mean','median','mode','std']
fg['disp']=s_n
s_n
# Out:
# [230.72187499999998, 196.3, 275.8, 123.93869383138194]

# %%
df=pd.DataFrame()
df['measure']=['mean','median','mode','std']
df['disp']=s_m
df
# Out:
#   measure        disp
# 0    mean  262.670000
# 1  median  304.500000
# 2    mode  360.000000
# 3     std  143.147345

# %%
sb.histplot(data['disp'],kde=True,color='red')
# Out:
# <Axes: xlabel='disp', ylabel='Count'>

# %%
sb.histplot(data['disp'],kde=True,color='k')
# Out:
# <Axes: xlabel='disp', ylabel='Count'>

# %%
sb.histplot(data['disp'],kde=True,color='blue')
# Out:
# <Axes: xlabel='disp', ylabel='Count'>

# %%
sb.histplot(df['disp'],kde=True,color='k')
# Out:
# <Axes: xlabel='disp', ylabel='Count'>

# %%
sb.histplot(df['disp'],kde=True,color='k')
pit.show()

# %%
#mean,mode,median and standard devation of random sampling 20
s_20=data.sample(n=20)
s_s=[s_20['disp'].mean(),
s_20['disp'].median(),
s_20['disp'].mode()[0],
s_20['disp'].std()]
s_s
# Out:
# [244.08500000000004, 241.5, 160.0, 110.15531750071901]

# %%
dh=pd.DataFrame()
dh['measure']=['mean','median','mode','std']
dh['disp']=s_s
dh
# Out:
#   measure        disp
# 0    mean  244.085000
# 1  median  241.500000
# 2    mode  160.000000
# 3     std  110.155318

# %%
sb.histplot(dh['disp'],kde=True,color='pink')
pit.show()

# %%
#mean,mode,median and standard devation of random sampling 30
s_30=data.sample(n=30)
s_f=[s_30['disp'].mean(),
s_30['disp'].median(),
s_30['disp'].mode()[0],
s_30['disp'].std()]
s_f
# Out:
# [226.90333333333336, 167.6, 275.8, 126.11540823944667]

# %%
dx=pd.DataFrame()
dx['measure']=['mean','median','mode','std']
dx['disp']=s_f
dx
# Out:
#   measure        disp
# 0    mean  232.020000
# 1  median  196.300000
# 2    mode  160.000000
# 3     std  126.905141

# %%
b=pd.DataFrame()
b['measures']=['mean','mode','median']
b['disp']=s_f
s_f
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 b=pd.DataFrame()
#       2 b['measures']=['mean','mode','median']
# ----> 3 b['disp']=s_f
#       4 s_f
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
# ...

# %%
sb.histplot(dx['disp'],kde=True,color='b')
pit.show()

# %% [markdown]
# #  task 3.2.2

# %%
#mean,mode,median and standard devation of population data
pop=[data['disp'].mean(),
data['disp'].median(),
data['disp'].mode()[0],
data['disp'].std()]
pop
# Out:
# [230.72187500000004, 196.3, 275.8, 123.93869383138194]

# %%
ds=pd.DataFrame()
ds['measure']=['mean','median','mode','std']
ds['disp']=pop
ds
# Out:
#   measure        disp
# 0    mean  230.721875
# 1  median  196.300000
# 2    mode  275.800000
# 3     std  123.938694

# %%
sb.histplot(ds['disp'],kde=True,color='b')
pit.show()

# %% [markdown]
# # task 3.2.3

# %%
d=pd.DataFrame()
d['measure']=['mean','median','mode','std']
d['pop']=pop
d['s_10']=s_s
d['s_20']=s_s
d['s_30']=s_f
d
# Out:
#   measure         pop        s_10        s_20        s_30
# 0    mean  230.721875  244.085000  244.085000  232.020000
# 1  median  196.300000  241.500000  241.500000  196.300000
# 2    mode  275.800000  160.000000  160.000000  160.000000
# 3     std  123.938694  110.155318  110.155318  126.905141

# %% [markdown]
# # task 3.2.4

# %% [markdown]
# # interpetation: if compare the data and sample data equal to 30 we do not find much diffrence  in mean ,median,mode,standard devation
