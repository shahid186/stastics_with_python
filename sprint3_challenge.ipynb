# %% [markdown]
# # task 1

# %% [raw]
# # what is the probobility  that the worker  is a female
# femal_labout=46%
# f.part.timer=25%
# femal_labout and f.part.timer=.46*.25=.115
# part_time_workers=17.4%=.174
#
# the probability thethe workers are female =.115/.174=0.660

# %% [markdown]
# # task 2

# %% [raw]
# #what is the probility that the worker belive that the more storage space ill increase the prodicity
# random_noise=70%
# storage=67%
# random_noise and storage=56%
# p(s & n)/p(n)=56/70=0.8

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit
import statistics as st
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')
import statistics as st

# %%
data=pd.read_csv('DS1_C5_S3_GamesSales_Data_Challenge.csv')
data
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...

# %% [markdown]
# # task 3.1

# %%
n=data.sample(20,replace=False,random_state=1)

# %%
n=data.sample(30,replace=False,random_state=1)

# %%
n.head()
# Out:
#                                                   Game  Year       Genre  \
# 189                           One Piece: Burning Blood  2018    Fighting
# 111                                           WWE 2K18  2019      Sports
# 551                         Sengoku Basara 4: Sumeragi  2017      Action
# 429  Earth Defense Force 2025.1: The Shadow of New ...  2017     Shooter
# 666                                 This Is The Police  2019  Simulation
#
#               Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 189  Namco Bandai Games                    0.21             0.26
# 111           2K Sports                    0.45             0.67
# 551              Capcom                    0.00             0.00
# 429         D3Publisher                    0.00             0.00
# 666          THQ Nordic                    0.01             0.00
#
#      Japan_Sales_M$  Other_Sales_M$  Global_Sales_M$
# 189            0.09            0.09             0.65
# ...

# %%
m=data.sample(20,replace=False,random_state=1)

# %%
s=data.sample(30,replace=False,random_state=1)

# %%
s=data.sample(30,replace=False,random_state=1)

# %%
s=data.sample(30,replace=False,random_state=1)

# %%
d=data.sample(30,replace=False,random_state=1)

# %%
g=data.sample(30,replace=True,random_state=1)

# %%
#random sampling without replacement
d=data.sample(30,replace=False,random_state=1)
d
# Out:
#                                                   Game  Year  \
# 189                           One Piece: Burning Blood  2018
# 111                                           WWE 2K18  2019
# 551                         Sengoku Basara 4: Sumeragi  2017
# 429  Earth Defense Force 2025.1: The Shadow of New ...  2017
# 666                                 This Is The Police  2019
# 537                                 Starblood Arena VR  2019
# 686                            Battle Garegga Rev.2018  2018
# 139                                              Ni-Oh  2019
# 69                         Dragon Age III: Inquisition  2016
# 335                        Dynasty Warriors 8: Empires  2016
# 47                        Resident Evil VII: Biohazard  2019
# 642                            Super Stardust Ultra VR  2018
# 274                 Dynasty Warriors 8: Xtreme Legends  2016
# 172           Disney Infinity 2.0: Marvel Super Heroes  2016
# ...

# %%
v=data.sample(15,replace=True,random_state=1)
v
# Out:
#                                                   Game  Year  \
# 37                                           Far Cry 5  2020
# 235                                  Tales of Zestiria  2017
# 72                             Need for Speed: Payback  2019
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018
# 144                           Injustice: Gods Among Us  2015
# 129                                        LEGO Worlds  2019
# 583                                         Dungeons 3  2019
# 508                    Dead or Alive Xtreme 3: Fortune  2018
# 390                                             MXGP 2  2018
# 281                                       Yooka-Laylee  2019
# 178                           The LEGO Movie Videogame  2016
# 276                        Saint Seiya: Soldiers' Soul  2017
# 254                                             Vampyr  2020
# 357           MXGP 3: The Official Motocross Videogame  2019
# ...

# %% [markdown]
# # task 3.2

# %%
##random sampling with replacement
h=data.sample(30,replace=True,random_state=1)
h
# Out:
#                                                   Game  Year  \
# 37                                           Far Cry 5  2020
# 235                                  Tales of Zestiria  2017
# 72                             Need for Speed: Payback  2019
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018
# 144                           Injustice: Gods Among Us  2015
# 129                                        LEGO Worlds  2019
# 583                                         Dungeons 3  2019
# 508                    Dead or Alive Xtreme 3: Fortune  2018
# 390                                             MXGP 2  2018
# 281                                       Yooka-Laylee  2019
# 178                           The LEGO Movie Videogame  2016
# 276                        Saint Seiya: Soldiers' Soul  2017
# 254                                             Vampyr  2020
# 357           MXGP 3: The Official Motocross Videogame  2019
# ...

# %%
data[::2].reset_index(drop=True)
# Out:
#                                             Game  Year             Genre  \
# 0                             Grand Theft Auto V  2016            Action
# 1                          Red Dead Redemption 2  2020  Action-Adventure
# 2                                        FIFA 18  2019            Sports
# 3                                Uncharted (PS4)  2018            Action
# 4                 Call of Duty: Infinite Warfare  2018           Shooter
# ..                                           ...   ...               ...
# 350  Date-A-Live Twin Edition: Rio Reincarnation  2019         Adventure
# 351                     Deception IV: Blood Ties  2017            Action
# 352                          Hyper Light Drifter  2019      Role-Playing
# 353             Darius Burst: Chronicle Saviours  2019            Action
# 354                               Super Meat Boy  2018          Platform
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %%
data[::2].reset_index(drop=True)
# Out:
#                                             Game  Year             Genre  \
# 0                             Grand Theft Auto V  2016            Action
# 1                          Red Dead Redemption 2  2020  Action-Adventure
# 2                                        FIFA 18  2019            Sports
# 3                                Uncharted (PS4)  2018            Action
# 4                 Call of Duty: Infinite Warfare  2018           Shooter
# ..                                           ...   ...               ...
# 350  Date-A-Live Twin Edition: Rio Reincarnation  2019         Adventure
# 351                     Deception IV: Blood Ties  2017            Action
# 352                          Hyper Light Drifter  2019      Role-Playing
# 353             Darius Burst: Chronicle Saviours  2019            Action
# 354                               Super Meat Boy  2018          Platform
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %%
data[::2].reset_index(drop=True)
# Out:
#                                             Game  Year             Genre  \
# 0                             Grand Theft Auto V  2016            Action
# 1                          Red Dead Redemption 2  2020  Action-Adventure
# 2                                        FIFA 18  2019            Sports
# 3                                Uncharted (PS4)  2018            Action
# 4                 Call of Duty: Infinite Warfare  2018           Shooter
# ..                                           ...   ...               ...
# 350  Date-A-Live Twin Edition: Rio Reincarnation  2019         Adventure
# 351                     Deception IV: Blood Ties  2017            Action
# 352                          Hyper Light Drifter  2019      Role-Playing
# 353             Darius Burst: Chronicle Saviours  2019            Action
# 354                               Super Meat Boy  2018          Platform
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %%
data[::2].reset_index(drop=True)
# Out:
#                                             Game  Year             Genre  \
# 0                             Grand Theft Auto V  2016            Action
# 1                          Red Dead Redemption 2  2020  Action-Adventure
# 2                                        FIFA 18  2019            Sports
# 3                                Uncharted (PS4)  2018            Action
# 4                 Call of Duty: Infinite Warfare  2018           Shooter
# ..                                           ...   ...               ...
# 350  Date-A-Live Twin Edition: Rio Reincarnation  2019         Adventure
# 351                     Deception IV: Blood Ties  2017            Action
# 352                          Hyper Light Drifter  2019      Role-Playing
# 353             Darius Burst: Chronicle Saviours  2019            Action
# 354                               Super Meat Boy  2018          Platform
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %% [markdown]
# # task 3.3

# %%
#systematic sampling 
data[::2].reset_index(drop=True)
# Out:
#                                             Game  Year             Genre  \
# 0                             Grand Theft Auto V  2016            Action
# 1                          Red Dead Redemption 2  2020  Action-Adventure
# 2                                        FIFA 18  2019            Sports
# 3                                Uncharted (PS4)  2018            Action
# 4                 Call of Duty: Infinite Warfare  2018           Shooter
# ..                                           ...   ...               ...
# 350  Date-A-Live Twin Edition: Rio Reincarnation  2019         Adventure
# 351                     Deception IV: Blood Ties  2017            Action
# 352                          Hyper Light Drifter  2019      Role-Playing
# 353             Darius Burst: Chronicle Saviours  2019            Action
# 354                               Super Meat Boy  2018          Platform
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %% [markdown]
# # task 3.4

# %%
#stratified sampling with respect to year and genre 
p=data.groupby(['Year'])
name=data['Year'].unique()
d=pd.DataFrame()
for i in name:
    g=p.get_group(i)
    k=g.sample(6)
    d=d.append(k)
d.shape
# Out:
# (36, 9)

# %%
b=data.groupby('Year')
name=data['Year'].unique()
k=pd.DataFrame()
for i in name:
    m=b.get_group(i)
    n=m.sample(6)
    l=k.append(n)
l.shape
# Out:
# (6, 9)

# %%
data.columns
# Out:
# Index(['Game', 'Year', 'Genre', 'Publisher', 'North_America_Sales_M$',
#        'Europe_Sales_M$', 'Japan_Sales_M$', 'Other_Sales_M$',
#        'Global_Sales_M$'],
#       dtype='object')

# %%
b=data.groupby(['Year'])
name=data['Year'].unique()
f=pd.DataFrame()
for i in name:
    b=b.get_group(i)
    k=b.sample(6)
    v=f.append(k)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       3 f=pd.DataFrame()
#       4 for i in name:
# ----> 5     b=b.get_group(i)
#       6     k=b.sample(6)
#       7     v=f.append(k)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'

# %%
data.columns
# Out:
# Index(['Game', 'Year', 'Genre', 'Publisher', 'North_America_Sales_M$',
#        'Europe_Sales_M$', 'Japan_Sales_M$', 'Other_Sales_M$',
#        'Global_Sales_M$'],
#       dtype='object')

# %%
b=data.groupby('Year')
name=data['Year'].unique()
k=pd.DataFrame()
for i in name:
    m=b.get_group(i)
    n=m.sample(6)
    l=k.append(n)
l.shape

# %%
n=data.groupby('Year')
a=[2015,2017,2016]
v=pd.DataFrame()
for i in a:
    v=n.get_group(i)
    c=v.sample(frac=.15)
    ch=v.append(c)

# %% [markdown]
# # task 3.5

# %%
#clustered sampling with respect to year and genre
year=data.groupby('Year')
name=[2015,2018,2020]
d=pd.DataFrame()
for i in name:
    g=year.get_group(i)
    k=g.sample(frac=.15)
    d=d.append(k)
d.reset_index(drop=True,inplace=True)  
d.shape
# Out:
# (37, 9)

# %%
y=data.groupby('year')
name[2015,2018,2020]

# %%
s_10=data.sample(10,random_state=1)
s_10=[s_10['North_America_Sales_M$'].mean(),
     s_10['North_America_Sales_M$'].median(),
     s_10['North_America_Sales_M$'].std()]
s_10
# Out:
# [0.219, 0.05500000000000001, 0.33896738617290145]

# %%
v=pd.DataFrame()
v['measure']=['mean','median','std']
v['North_America_Sales_M$']=s_10
s_10
# Out:
# [0.219, 0.05500000000000001, 0.33896738617290145]

# %% [markdown]
# # 3.1.1

# %%
#mean ,median,standard devatation ,with sample size 10 ,20,30,40
s_10=data.sample(10,random_state=1)
s_10=[s_10['North_America_Sales_M$'].mean(),
s_10['North_America_Sales_M$'].median(),
s_10['North_America_Sales_M$'].std()]
s_10
# Out:
# [0.219, 0.05500000000000001, 0.33896738617290145]

# %%
d=pd.DataFrame()
d['measure']=['mean','median','std']
d['North_America_Sales_M$']=s_10
d
# Out:
#   measure  North_America_Sales_M$
# 0    mean                0.219000
# 1  median                0.055000
# 2     std                0.338967

# %%
sb.histplot(d['North_America_Sales_M$'],kde=True)
# Out:
# <AxesSubplot:xlabel='North_America_Sales_M$', ylabel='Count'>

# %%
#sampling 20
s_20=data.sample(20,random_state=1)
s_20=[s_20['North_America_Sales_M$'].mean(),
s_20['North_America_Sales_M$'].median(),
s_20['North_America_Sales_M$'].std()]
s_20
# Out:
# [0.377, 0.15, 0.7082082655324075]

# %%
f=pd.DataFrame()
f['measure']=['mean','mode','median']
f['North_America_Sales_M$']=s_20
f
# Out:
#   measure  North_America_Sales_M$
# 0    mean                0.377000
# 1    mode                0.150000
# 2  median                0.708208

# %%
sb.histplot(f['North_America_Sales_M$'],kde=True)
# Out:
# <AxesSubplot:xlabel='North_America_Sales_M$', ylabel='Count'>

# %%
#sampling 30
s_30=data.sample(30,random_state=1)
s_30=[s_30['North_America_Sales_M$'].mean(),
s_30['North_America_Sales_M$'].median(),
s_30 ['North_America_Sales_M$'] .std()]
s_30
# Out:
# [0.3543333333333333, 0.1, 0.6360908812389957]

# %%
g=pd.DataFrame()
g['measure']=['mean','median','std']
g['North_America_Sales_M$']=s_30
g
# Out:
#   measure  North_America_Sales_M$
# 0    mean                0.354333
# 1  median                0.100000
# 2     std                0.636091

# %%
sb.histplot(g['North_America_Sales_M$'],kde=True,color='k')
# Out:
# <AxesSubplot:xlabel='North_America_Sales_M$', ylabel='Count'>

# %%
#sampling 40
s_40=data.sample(40,random_state=1)
s_40=[s_40['North_America_Sales_M$'].mean(),
s_40['North_America_Sales_M$'].median(),
s_40 ['North_America_Sales_M$'] .std()]
s_40
# Out:
# [0.294, 0.065, 0.5717530397484026]

# %%
t=pd.DataFrame()
t['measure']=['mean','median','std']
t['North_America_Sales_M$']=s_40
t
# Out:
#   measure  North_America_Sales_M$
# 0    mean                0.294000
# 1  median                0.065000
# 2     std                0.571753

# %%
sb.histplot(t['North_America_Sales_M$'],kde=True,color='b');

# %% [markdown]
# # task 3.2.2

# %%
#mean ,statndard devation of populationd ata
pop=[data['North_America_Sales_M$'].mean(),
data['North_America_Sales_M$']  .median() ,  
data['North_America_Sales_M$'] .std()]  
pop
# Out:
# [0.2984062059238376, 0.07, 0.6597096380341148]

# %%
p=pd.DataFrame()
p['measure']=['mean','median','std']
p['North_America_Sales_M$']=pop
p
# Out:
#   measure  North_America_Sales_M$
# 0    mean                0.298406
# 1  median                0.070000
# 2     std                0.659710

# %%
sb.histplot(p['North_America_Sales_M$'],kde=True)
pit.show()

# %% [markdown]
# # task 3.2.3

# %%
pop=[data['Global_Sales_M$'].mean(),
data['Global_Sales_M$']  .median() ,  
data['Global_Sales_M$'] .std()]  
pop
# Out:
# [0.8398025387870189, 0.17, 1.8539147663671114]

# %%
p=pd.DataFrame()
p['measure']=['mean','median','std']
p['Global_Sales_M$']=pop
p
# Out:
#   measure  Global_Sales_M$
# 0    mean         0.839803
# 1  median         0.170000
# 2     std         1.853915

# %%
sb.histplot(p['Global_Sales_M$'],kde=True)
pit.show()

# %%
p=data.groupby(['Year'])
name=data['Year'].unique()
d=pd.DataFrame()
for i in name:
    g=p.get_group(i)
    k=g.sample(6)
    d=d.append(k)
d
# Out:
#                                                   Game  Year  \
# 184                                     Rocksmith 2016  2016
# 518                          Nobunaga no Yabou: Souzou  2016
# 35                                           Far Cry 4  2016
# 354                              Guilty Gear Xrd: Sign  2016
# 120                    Metal Gear Solid: Ground Zeroes  2016
# 210                                Lords of the Fallen  2016
# 503                          Legend of Kay Anniversary  2017
# 117                                       Project CARS  2017
# 73                             Destiny: The Taken King  2017
# 343                                    Toukiden Kiwami  2017
# 581                 Assassin's Creed Chronicles: China  2017
# 540         Nitroplus Blasterz: Heroines Infinite Duel  2017
# 654                                            Armello  2020
# 232                          Dissidia Final Fantasy NT  2020
# ...

# %%
sb.histplot(d['Global_Sales_M$'],kde=True)
pit.show()

# %% [markdown]
# # interpetation: if compare popolation data  and sample data size equal to 30 we find that mean, mode ,median is more in population data as compered to stratified  sampling
